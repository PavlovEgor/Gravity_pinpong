# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D

# %%
tmp = np.loadtxt("../data/x_finish.txt").T
X_finish = tmp[0]
Y_finish = tmp[1]
R_finish = tmp[2]
Phi_finish = tmp[3]
E = 0.4904509063

# %%
R_min = np.min(R_finish)
R_max = np.max(R_finish)
angle = np.linspace(0, 2 * np.pi, 1000)

R_max_posible = 1 / E

# %%
plt.scatter(R_finish, Phi_finish, s=1)
plt.plot([R_min, R_min], [0, 2 * np.pi], '-', c='tab:red')
# plt.plot([R_min, R_min], [np.pi * 3 / 2, 2 * np.pi], '-', c='tab:red')
plt.show()

plt.scatter(X_finish, Y_finish, s=1)
plt.plot(R_max_posible * np.cos(angle), R_max_posible * np.sin(angle))
plt.show()
